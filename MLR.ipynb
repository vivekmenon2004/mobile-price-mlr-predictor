# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/My Drive/Colab Notebooks")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_excel('Mobile_MLR_Dataset.xlsx')
dataset
# Out:
#        Brand  RAM_GB  Storage_GB  Battery_mAh  Camera_MP  Display_Inch  \
# 0    Samsung       8         128         5000         64           6.5
# 1    Samsung       6         128         4500         48           6.4
# 2    Samsung      12         256         5000        108           6.7
# 3      Redmi       4          64         5000         50           6.5
# 4      Redmi       6         128         5000         64           6.6
# 5      Redmi       8         128         6000         64           6.7
# 6     Realme       6         128         5000         64           6.5
# 7     Realme       8         128         5000        108           6.6
# 8     Realme       4          64         5000         50           6.5
# 9    OnePlus       8         128         4500         50           6.7
# 10   OnePlus      12         256         5000         64           6.7
# 11   OnePlus      16         256         5000        108           6.8
# 12      Vivo       6         128         4500         64           6.4
# 13      Vivo       8         128         5000         64           6.5
# 14      Vivo       4          64         5000         50           6.5
# 15      Oppo       6         128         4500         64           6.4
# 16      Oppo       8         128         5000         64           6.5
# 17      Oppo       4          64         5000         50           6.5
# 18     Apple       6         128         3200         12           6.1
# 19     Apple       8         256         3500         48           6.7
# 20     Apple       4          64         3000         12           6.1
# 21  Motorola       6         128         5000         50           6.5
# 22  Motorola       8         128         5000         64           6.6
# 23  Motorola       4          64         5000         50           6.5
# 24     Nokia       4          64         4000         48           6.3
# 25     Nokia       6         128         4500         64           6.4
# 26     Nokia       8         128         5000         64           6.5
# 27      Poco       6         128         5000         64           6.6
# 28      Poco       8         128         6000         64           6.7
# 29      Poco      12         256         5000        108           6.7
# 30   Infinix       4          64         5000         50           6.5
# 31   Infinix       6         128         5000         64           6.6
# 32   Infinix       8         128         6000         64           6.7
# 33      iQOO       8         128         4500         64           6.6
# 34      iQOO      12         256         4700        108           6.7
# 35      iQOO      16         256         5000         50           6.8
# 36    Google       8         128         4500         50           6.4
# 37    Google      12         256         4800         50           6.7
# 38      Sony       8         128         4500         64           6.5
# 39      Sony      12         256         5000        108           6.8
# 40      Asus       8         128         6000         64           6.7
# 41      Asus      12         256         6000         64           6.8
# 42      Lava       4          64         5000         50           6.5
# 43      Lava       6         128         5000         64           6.6
# 44  Micromax       4          64         5000         50           6.5
# 45  Micromax       6         128         5000         64           6.6
# 46     Honor       6         128         4500         64           6.5
# 47     Honor       8         128         5000        108           6.7
# 48   Nothing       8         128         4500         50           6.6
# 49   Nothing      12         256         4700         50           6.7
#
#     Processor_GHz  Brand_Rating  Price
# 0             2.4           4.5  22000
# 1             2.2           4.4  18000
# 2             2.8           4.6  35000
# 3             2.0           4.2  12000
# 4             2.2           4.3  15000
# 5             2.4           4.4  18000
# 6             2.3           4.3  16000
# 7             2.5           4.4  20000
# 8             2.1           4.1  11000
# 9             2.8           4.6  32000
# 10            3.0           4.7  45000
# 11            3.2           4.8  55000
# 12            2.3           4.2  17000
# 13            2.5           4.3  21000
# 14            2.0           4.1  13000
# 15            2.3           4.2  17500
# 16            2.5           4.3  22000
# 17            2.1           4.0  12500
# 18            3.0           4.8  70000
# 19            3.2           4.9  95000
# 20            2.8           4.7  60000
# 21            2.2           4.1  16000
# 22            2.4           4.2  19000
# 23            2.0           4.0  12000
# 24            2.0           3.9  11000
# 25            2.2           4.0  15000
# 26            2.3           4.1  18000
# 27            2.5           4.3  17000
# 28            2.6           4.4  21000
# 29            2.8           4.5  26000
# 30            2.0           4.0  10000
# 31            2.2           4.1  13000
# 32            2.3           4.2  16000
# 33            2.8           4.4  25000
# 34            3.0           4.5  35000
# 35            3.2           4.6  42000
# 36            2.9           4.7  60000
# 37            3.1           4.8  80000
# 38            2.8           4.3  45000
# 39            3.0           4.4  60000
# 40            2.9           4.4  40000
# 41            3.1           4.5  50000
# 42            2.0           3.8   9000
# 43            2.2           4.0  12000
# 44            2.0           3.7   8500
# 45            2.2           3.9  11000
# 46            2.4           4.2  20000
# 47            2.6           4.3  25000
# 48            2.7           4.5  32000
# 49            3.0           4.6  38000

# %%
X = dataset.drop('Price', axis=1)
y = dataset['Price']

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

ct = ColumnTransformer(
    transformers=[('encoder', OneHotEncoder(drop='first'), ['Brand'])],
    remainder='passthrough'
)

X = ct.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0
)

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

print("Predicted Values:\n", y_pred)
# Out:
# Predicted Values:
#  [12548.921515   42857.37617129 36140.87855784 51862.53195259
#  37939.70275143 13860.79088297 44945.11978108 17681.29096878
#  22375.99460704 19159.26082748]

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print("R2 Score:", r2)
# Out:
# R2 Score: 0.8434167736109902

# %%
import pickle
pickle.dump(regressor, open('mobile_price_model.pkl', 'wb'))

# %%
from google.colab import files
files.download('mobile_price_model.pkl')
